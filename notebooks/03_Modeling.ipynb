# %% [markdown]
# # 03 - Modeling
#
# Train, compare, and evaluate volatility models.

# %%
import sys
from pathlib import Path
import pandas as pd
import json

ROOT = Path.cwd().parent
sys.path.insert(0, str(ROOT))

from src.preprocessing import load_processed
from src.training import run_full_training_pipeline
from src.config import COMPARISON_PATH, METRICS_PATH

df = load_processed('processed_combined.csv')
meta = run_full_training_pipeline(df, tune=True, tune_model='xgboost')
meta

# %%
pd.read_csv(COMPARISON_PATH)

# %%
json.loads(METRICS_PATH.read_text())
