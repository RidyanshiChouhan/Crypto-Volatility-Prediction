# %% [markdown]
# # 02 - Feature Engineering
#
# 15+ technical indicators and next-day volatility target.

# %%
import sys
from pathlib import Path
ROOT = Path.cwd().parent
sys.path.insert(0, str(ROOT))

from src.preprocessing import load_processed
from src.feature_engineering import get_feature_columns, compute_feature_importance_correlation, TARGET_COL

df = load_processed('processed_combined.csv')
features = get_feature_columns(df)
print(f'{len(features)} features')
features

# %%
importance = compute_feature_importance_correlation(df)
importance.head(15)

# %%
df[['date','symbol','rolling_volatility_7', TARGET_COL]].dropna().tail()
